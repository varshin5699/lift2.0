# %% [markdown]
# <a href="https://colab.research.google.com/github/varshin5699/lift2.0/blob/main/lift20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# !pip install nest-asyncio
import nest_asyncio
nest_asyncio.apply()

# %%
  # !pip install ultralytics
  # !pip install supervision
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.4/617.4 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 2.0 MB/s eta 0:00:00
# ...

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))

  # Show the image which was just taken.
 # display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to photo.jpg

# %%
from ultralytics import YOLO
import supervision as sv
import numpy
'''
# load a pretrained YOLOv8n model
model = YOLO("yolov8n.pt", "v8")

# predict on an image
detection_output = model.predict(source="/content/WhatsApp Video 2023-10-06 at 11.29.04.mp4", conf=0.25, save=True)

# Display tensor array
'''
class detector() :

  def predict(self, frame) :
    results = self.model(frame)
    return results
'''
box_annotator = sv.BoxAnnotator(
        thickness=2,
        text_thickness=2,
        text_scale=1
)
"""
detection_output = sv.Detections.from_ultralytics(detection_output)
labels = [
            f"{model.model.names[class_id]} {confidence:0.2f}"
            for _, confidence, class_id, _
            in detection_output
        ]
"""


for detected in detection_output :

  #if detected.class_id == 0 :
  # if detected._len_() :
    print(detected.__len__())
# Display numpy array
#print(detection_output[0].numpy())'''
# Out:
# '\nbox_annotator = sv.BoxAnnotator(\n        thickness=2,\n        text_thickness=2,\n        text_scale=1\n)\n"""\ndetection_output = sv.Detections.from_ultralytics(detection_output)\nlabels = [\n            f"{model.model.names[class_id]} {confidence:0.2f}"\n            for _, confidence, class_id, _\n            in detection_output\n        ]\n"""\n\n\nfor detected in detection_output :\n    \n  #if detected.class_id == 0 :\n  # if detected._len_() :  \n    print(detected.__len__())\n# Display numpy array\n#print(detection_output[0].numpy())'

# %%
# !pip install fontstyle
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fontstyle: filename=fontstyle-1.0.1.2-py3-none-any.whl size=6395 sha256=a42dc9b892878fe9e994b912daeb042d33ea494426456c9e5af3971bb2668d38
#   Stored in directory: /root/.cache/pip/wheels/ee/f8/dc/2978abb783862b07377b4a788b2716782f2d0cdafdb6f71f1d
# Successfully built fontstyle
# ...

# %% [markdown]
# if the code doesn't run on colab, try running it on vscode

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Sep 26 15:22:42 2023

@author: srivarshinees
"""
import os
import threading
import time
import asyncio
import random
import fontstyle as fs

'''def ishelp(): funtion to check if the person has mobility issues'''
def ishelp(el):
    return False
def person_still_there(c): #c-camera number
    model = YOLO("yolov8n.pt", "v8")

    # predict on an image

    detection_output = model.predict(source="/content/WhatsApp Video 2023-10-06 at 11.54.08.mp4", conf=0.25, save=True,show=False) if c==4 else model.predict(source="/content/WhatsApp Video 2023-10-06 at 11.29.04.mp4", conf=0.25, save=True,show=False)


    # Display tensor array
    '''
    class detector() :

      def predict(self, frame) :
        results = self.model(frame)
        return results
    '''
    box_annotator = sv.BoxAnnotator(
            thickness=2,
            text_thickness=2,
            text_scale=1
    )
    """
    detection_output = sv.Detections.from_ultralytics(detection_output)
    labels = [
                f"{model.model.names[class_id]} {confidence:0.2f}"
                for _, confidence, class_id, _
                in detection_output
            ]
    """


    for detected in detection_output :

      #if detected.class_id == 0 :
      # if detected._len_() :
        #print(detected.__len__())
        return True if detected.__len__()!=0 else False
    # Display numpy array
    #print(detection_output[0].numpy())
'''should change above function'''
def allless(a,cr):
    #a is the list part of pq and cr is the curr_floor member of lift
    t=True
    for x in a:
        if x>cr:
            t=False
    return t



class lift(object):
    #setting the maximum capacity of the lift to 20

    def __init__(self,floors):
        self.floors=floors
       # self.next_floor= next_floor if (next_floor<=floors) else print("ERROR\n")
        #self.capc=capc
        self.curr_floor=0
        self.mode=0 #0-asc, 1-desc, by default starts with asc
        self.cap_max=20
        self.capc=0
        self.next_floor=0


            #os.kill(os.getpid(), signal.SIGKILL)

        #signal to be passed to the hardware to halt the lift so it doesn't move
    def move(self,delelmt):
        #time.sleep(3)
        self.curr_floor=delelmt #delelmt is the return value of delete of that particular object in the __main__
    '''the below capc can also be removed since it could be made a part of the hardware'''
    def comp_capc(self, pl_count1,pl_count2): #ppl count is the number of people that are getting inside the lift
        self.capc=self.capc+pl_count1-pl_count2
        if(self.capc>self.cap_max):
            print("MAX CAPACITY REACHED\n")
            time.sleep(2)
    def isasc(self,pq):
        if(self.curr_floor==self.floors  or allless(pq.rq,self.curr_floor)):
            self.mode=1
        else:
            self.mode=0

    def display(self):
        print(fs.apply("currently in the floor "+str(self.curr_floor),'bold/Italic/blue'))




class priority_queue(object):
    def __init__(self):
        self.rq=[]
        #self.rear=0
        #self.front=-1

    def palr(self,el):
        return el in self.rq
    def addel(self,el):
        if(self.palr(el)!=True):
            self.rq.append(el)
    def delete(self,asc):

            max_ind=0
            max_el=0
            if(asc==0): #asc is the value of lift.mode
                for i in range(len(self.rq)):
                    if self.rq[i]<max_el or ishelp(self.rq[i]):
                        max_ind=i
                        max_el = self.rq[max_ind] if ishelp(self.rq[i])==False else self.rq[i]

                it=self.rq[max_ind]
                del self.rq[max_ind]
                return it
            else:
                for i in range(len(self.rq)):
                    if self.rq[i]>max_el or ishelp(self.rq[i]):
                        max_ind=i
                        max_el= self.rq[max_ind] if ishelp(self.rq[i])==False else self.rq[i]
                it=self.rq[max_ind]
                del self.rq[max_ind]
                return it

    def empty(self):
        return self.rq.isempty()


async def pre_empt(pq,w=-1):
    t=random.randint(1,5)
    if(t!=w): pq.addel(int(t))
    print(" added floor " +str(t))
    print(pq.rq)
    return(pq.rq)


async def liftki(pq,lif): ##lift stops temp in a floor
    #lif.display()
    # here it requests to find out the next stop
    await pre_empt(pq)
    await asyncio.sleep(2)
    await pre_empt(pq)
    await asyncio.sleep(2)
    await pre_empt(pq)
    await asyncio.sleep(2)
    t=pq.delete(lif.mode)
    print(len(pq.rq))
    while(person_still_there(t)==False ):

        t=pq.delete(lif.mode)
        lif.isasc(pq)

        if(len(pq.rq))==0:
            time.sleep(1)
            break
            #change this to make it sleep until another pre-emption is made
    # before moving  update these
    p1=int(input("enter number of people entering "))
    p2=int(input("enter number of people leaving "))
    lif.comp_capc(p1,p2)
    #lif.curr_floor=t  invoke a move(t) and update current floor, awaiting for a pre-emption
    await move(pq,lif,t)

async def move(pq,lif,t):
    print("moving")
    await asyncio.sleep(1)

    await pre_empt(pq,t)
    await asyncio.sleep(2)
    await pre_empt(pq,t)
    await asyncio.sleep(2)

    lif.curr_floor=t

    print("asc" if lif.mode==0 else "dsc")
    lif.display()
    await asyncio.sleep(3)
    await liftki(pq,lif)

lif=lift(5)
pq=priority_queue()

asyncio.run(liftki(pq,lif))
# Out:
#  added floor 3
# [3]
#  added floor 1
# [3, 1]
#  added floor 5
# [3, 1, 5]
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/563) /content/WhatsApp Video 2023-10-06 at 11.29.04.mp4: 352x640 1 person, 9.4ms
# 2
# video 1/1 (2/563) /content/WhatsApp Video 2023-10-06 at 11.29.04.mp4: 352x640 1 person, 10.7ms
# video 1/1 (3/563) /content/WhatsApp Video 2023-10-06 at 11.29.04.mp4: 352x640 1 person, 9.6ms
# ...
